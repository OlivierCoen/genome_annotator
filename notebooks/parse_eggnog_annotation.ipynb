# %%
import pandas as pd

# %%
file = "/home/olivier/repositories/genome_annotator/work/9d/462df67aaf287602136fc150526bef/test_12_ctg.emapper.annotations"
df = pd.read_csv(file, sep='\t', skiprows=4)

# %%
df
# Out:
#                query            seed_ortholog         evalue  score  \
# 0    test_12_ctg1099      5551.XP_003238043.1   1.810000e-35  145.0
# 1    test_12_ctg1105      6087.XP_002153953.1  3.680000e-244  693.0
# 2    test_12_ctg1112  7897.ENSLACP00000014670   1.980000e-05   55.5
# 3    test_12_ctg1147      5872.XP_004829764.1   2.810000e-20  101.0
# 4    test_12_ctg1181     69319.XP_008549718.1   3.300000e-27  117.0
# ..               ...                      ...            ...    ...
# 214   test_12_ctg798        639282.DEFDS_1956   1.150000e-05   55.1
# 215   test_12_ctg805     63400.XP_003014029.1  7.280000e-157  480.0
# 216   test_12_ctg821        6412.HelroP185778   3.010000e-49  181.0
# 217   test_12_ctg834    263815.XP_007874366.1   5.990000e-39  149.0
# 218   test_12_ctg847            588596.U9SMF3   8.650000e-22  101.0
#
#                                             eggNOG_OGs  \
# 0    KOG1940@1|root,KOG1940@2759|Eukaryota,38TY1@33...
# ...
